# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import helper_functions
import sklearn
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# # Preparing the data
# The data currently looks like this:
# * machine name
# * app information
# * performance counters
#
# We will first convert the data to an intermediate form as:
# * source machine name
# * app information (app, args, ranks)
# * performance counters from source machine
# * target machine name
# * source machine metrics (RAJAPerfSuite benchmarking results)
# * target machine metrics (RAJAPerfSuite benchmarking results)
#
# Then, we will convert the data to the final form as:
# * performance counters from source machine
# * source machine metrics (RAJAPerfSuite benchmarking results)
# * target machine metrics (RAJAPerfSuite benchmarking results)
#
# Note that
# * source machine indicates where the performance counters were gathered
# * target machine indicates which machine's performance we're trying to predict
# * NaN value is replaced with 0.0

# %% [markdown]
# ## Reading in the application performance counter data

# %%
data_df = helper_functions.get_data()
data_df = helper_functions.normalize(data_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <module>
#       1 data_df = helper_functions.get_data()
# ----> 2 data_df = normalize(data_df)
#
# NameError: name 'normalize' is not defined

# %% [markdown]
# ### Information about the data (optional)

# %%
data_df['sid'] = range(1, len(data_df) + 1)
label_num_samples_per_mach, num_samples_per_mach = helper_functions.show_data_summary(data_df, 'machine')
# Out:
# Num samples =  3075
# Num columns =  22
#
# ---------------------------------------------
# Num apps =  14
#     -  comd 42
#     -  cosmoflow 37
#     -  deepcam 75
#     -  minigan 42
#     -  miniqmc 43
#     -  minitri 43
#     -  kripke.exe 630
#     -  laghos 976
#     -  miniFE.x 200
#     -  sw4lite 65
#     -  TestDfft 228
#     -  XSBench 71
#     -  amg 47
#     -  miniVite 576
#
# ---------------------------------------------
# Num machines =  6
#     -  corona 47
#     -  corona-cpu 344
#     -  lassen 224
#     -  lassen-cpu 215
#     -  quartz 1207
#     -  ruby 1038
# ---------------------------------------------
#
# ---------------------sample 1------------------
#  machine                   corona
# app                         comd
# args                         NaN
# ranks                          1
# duration                  0.0333
# BR_INS               116000000.0
# LD_INS               817920249.0
# SR_INS               250494660.0
# TOT_INS             2014000000.0
# L1_LDM                73352868.0
# L1_STM                      -1.0
# L2_LDM                      -1.0
# L2_STM                      -1.0
# FP_SINGLE                   -1.0
# FP_DOUBLE                   -1.0
# ARITH                       -1.0
# IO Bytes Read           293744.0
# IO Bytes Written        206264.0
# MEM_WCY              354191814.0
# REALTIME (sec)          0.475758
# Overhead                1.522242
# sid                            1
# Name: 0, dtype: object
#
# ---------------------sample 2------------------
#  machine                   corona
# app                         comd
# args                         NaN
# ranks                          1
# duration                  0.0333
# BR_INS               152000000.0
# LD_INS              1082901656.0
# SR_INS               328072104.0
# TOT_INS             2632000000.0
# L1_LDM                97475957.0
# L1_STM                      -1.0
# L2_LDM                      -1.0
# L2_STM                      -1.0
# FP_SINGLE                   -1.0
# FP_DOUBLE                   -1.0
# ARITH                       -1.0
# IO Bytes Read           293744.0
# IO Bytes Written        206264.0
# MEM_WCY              467561963.0
# REALTIME (sec)          0.626035
# Overhead                1.371965
# sid                            2
# Name: 1, dtype: object

# %% [markdown]
# ## Dropping the samples that cannot be used to calculate relative performance

# %%
# For calculating relative performance, we need at least a pair of observations from two different machines.
# If we have only a sample from an application with a specific string of arguments run by a specific number of ranks,
# we cannot calculate relative performance. Therefore, we remove those samples.
data_df = helper_functions.drop_unmatched_rows(data_df)
label_num_samples_per_mach, num_samples_per_mach = helper_functions.show_data_summary(data_df, 'machine')
# Out:
# Num samples =  2423
# Num columns =  22
#
# ---------------------------------------------
# Num apps =  8
#     -  kripke.exe 630
#     -  laghos 693
#     -  miniFE.x 153
#     -  sw4lite 37
#     -  TestDfft 216
#     -  XSBench 71
#     -  amg 47
#     -  miniVite 576
#
# ---------------------------------------------
# Num machines =  5
#     -  corona-cpu 344
#     -  lassen 177
#     -  lassen-cpu 215
#     -  quartz 867
#     -  ruby 820
# ---------------------------------------------
#
# ---------------------sample 1------------------
#  machine                                                   corona-cpu
# app                                                       kripke.exe
# args                --niter 10 --pmethod bj --groups 16 --legendre 0
# ranks                                                              1
# duration                                                      0.0666
# BR_INS                                                   444000000.0
# LD_INS                                                   665884542.0
# SR_INS                                                   375056450.0
# TOT_INS                                                 2046000000.0
# L1_LDM                                                    63538758.0
# L1_STM                                                          -1.0
# L2_LDM                                                          -1.0
# L2_STM                                                          -1.0
# FP_SINGLE                                                       -1.0
# FP_DOUBLE                                                       -1.0
# ARITH                                                           -1.0
# IO Bytes Read                                               538330.0
# IO Bytes Written                                           3059100.0
# MEM_WCY                                                  707388823.0
# REALTIME (sec)                                              1.406057
# Overhead                                                    2.589943
# sid                                                               48
# Name: 47, dtype: object
#
# ---------------------sample 2------------------
#  machine                                                   corona-cpu
# app                                                       kripke.exe
# args                --niter 10 --pmethod bj --groups 16 --legendre 1
# ranks                                                              1
# duration                                                        0.05
# BR_INS                                                   438000000.0
# LD_INS                                                   672294542.0
# SR_INS                                                   378443244.0
# TOT_INS                                                 2014000000.0
# L1_LDM                                                    64233891.0
# L1_STM                                                          -1.0
# L2_LDM                                                          -1.0
# L2_STM                                                          -1.0
# FP_SINGLE                                                       -1.0
# FP_DOUBLE                                                       -1.0
# ARITH                                                           -1.0
# IO Bytes Read                                               541418.0
# IO Bytes Written                                           3059100.0
# MEM_WCY                                                  739324398.0
# REALTIME (sec)                                              1.433762
# Overhead                                                    1.566238
# sid                                                               49
# Name: 48, dtype: object

# %%
print(data_df['ranks'].unique())
# Out:
# [ 1 32]

# %% [markdown]
# ## Filter out samples of Corona (optional)

# %%
data_df = data_df.loc[data_df['machine'] != 'corona']

# %% [markdown]
# ## Filter out samples of the app 'sw4lite' (optional)

# %%
data_df = data_df.loc[data_df['app'] != 'sw4lite']

# %% [markdown]
# ## Renaming **machine** row to **source machine**

# %%
# This is to prepare source and target machine combinations
machines = data_df['machine'].unique()
data_df = data_df.rename(columns={'machine': 'source machine'})

# %% [markdown]
# ## Duplicating rows with multiple target machines

# %%
# If there exist N samples of a specific app+args+rank combination collected from N machines,
# the sample from each source machine is replicated to N target machines including itself.
# The new sample includes an extra column 'target machine'.
# Consequently, total NxN samples are created out of the original N samples.
data_df = helper_functions.create_machine_combinations(data_df)
label_num_samples_per_mach, num_samples_per_mach = helper_functions.show_data_summary(data_df, 'source machine')
# Out:
# Num samples =  4493
# Num columns =  26
#
# ---------------------------------------------
# Num apps =  7
#     -  laghos 1614
#     -  kripke.exe 840
#     -  miniVite 1152
#     -  TestDfft 468
#     -  amg 109
#     -  XSBench 96
#     -  miniFE.x 214
#
# ---------------------------------------------
# Num machines =  3
#     -  quartz 1921
#     -  ruby 1827
#     -  lassen 745
# ---------------------------------------------
#
# ---------------------sample 1------------------
#  source machine                            quartz
# app                                       laghos
# args                     -p 1 -dim 2 -rs 2 -tf 3
# ranks                                          1
# duration                                  0.1833
# BR_INS                              8200000000.0
# LD_INS                             19434000000.0
# SR_INS                              6256000000.0
# TOT_INS                            59954000000.0
# L1_LDM                               202000000.0
# L1_STM                               160000000.0
# L2_LDM                                 6000000.0
# L2_STM                                 4000000.0
# FP_SINGLE                              3259234.0
# FP_DOUBLE                          11407387387.0
# ARITH                               8376314544.0
# IO Bytes Read                            37771.0
# IO Bytes Written                       2205834.0
# MEM_WCY                              912000000.0
# REALTIME (sec)                          8.763434
# PM_MATH_FLOP_CMPL                            NaN
# L1-DCACHE-LOAD-MISSES                        NaN
# L1-ICACHE-LOAD-MISSES                        NaN
# Overhead                                2.234566
# sid                                           13
# target machine                            quartz
# Name: 12, dtype: object
#
# ---------------------sample 2------------------
#  source machine                            quartz
# app                                       laghos
# args                     -p 1 -dim 2 -rs 2 -tf 3
# ranks                                          1
# duration                                  0.1833
# BR_INS                              8200000000.0
# LD_INS                             19434000000.0
# SR_INS                              6256000000.0
# TOT_INS                            59954000000.0
# L1_LDM                               202000000.0
# L1_STM                               160000000.0
# L2_LDM                                 6000000.0
# L2_STM                                 4000000.0
# FP_SINGLE                              3259234.0
# FP_DOUBLE                          11407387387.0
# ARITH                               8376314544.0
# IO Bytes Read                            37771.0
# IO Bytes Written                       2205834.0
# MEM_WCY                              912000000.0
# REALTIME (sec)                          8.763434
# PM_MATH_FLOP_CMPL                            NaN
# L1-DCACHE-LOAD-MISSES                        NaN
# L1-ICACHE-LOAD-MISSES                        NaN
# Overhead                                2.234566
# sid                                           13
# target machine                              ruby
# Name: 12, dtype: object

# %% [markdown]
# ## Generating plots for data distribution (optional)

# %%
import matplotlib.pyplot as plt
import textwrap
# Plot number of samples per target source machine pair

s_mach = data_df['source machine'].unique()
t_mach = data_df['target machine'].unique()
label_num_samples_per_pair = []
num_samples_per_pair = []
for s in s_mach:
    for t in t_mach:
        if t == s:
            continue
        else:
            label_num_samples_per_pair.append(s + ' to ' + t)
            num_samples_per_pair.append(len(data_df[(data_df['source machine'] == s) & (data_df['target machine'] == t)]))

helper_functions.set_plt_size()
plt.rcParams["figure.figsize"] = (15,5)
fig, (ax0, ax1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [4, 12]})
# plt.ylim(0, 12)


ax0.bar(label_num_samples_per_mach, num_samples_per_mach)
ax1.bar(label_num_samples_per_pair, num_samples_per_pair)
# plt.bar(x, y)
y_max = 2000

ax1.title.set_text("Samples per source-target machine pair")
ax1.yaxis.set_label_text("Number of samples")
ax1.xaxis.set_label_text("Source-target machine pair")
ax1.set_xticks(np.arange(0, (len(label_num_samples_per_pair)+1)))
ax1.set_ylim([0, y_max])
ax1.grid(axis='y')

ax0.title.set_text("Samples per machine")
ax0.yaxis.set_label_text("Number of samples")
ax0.xaxis.set_label_text("Machine")
ax0.set_xticks(np.arange(0, (len(label_num_samples_per_mach)+1)))
ax0.set_ylim([0, y_max])
ax0.grid(axis='y')

# addlabels(x, y)
# axs[0].set_
helper_functions.wrap_labels(ax0, 10, 90)
helper_functions.wrap_labels(ax1, 10, 90)

plt.show()
# for i in range(len(x)):
#     print(x[i], y[i])  
plt.savefig("num_samples.png")

# %% [markdown]
# ## Merge machine metric data

# %%
data_df = helper_functions.merge_benchmarks(data_df)
_,_ = helper_functions.show_data_summary(data_df, 'source machine')
# Out:
# Num samples =  4493
# Num columns =  154
#
# ---------------------------------------------
# Num apps =  7
#     -  laghos 1614
#     -  kripke.exe 840
#     -  miniVite 1152
#     -  TestDfft 468
#     -  amg 109
#     -  XSBench 96
#     -  miniFE.x 214
#
# ---------------------------------------------
# Num machines =  3
#     -  quartz 1921
#     -  ruby 1827
#     -  lassen 745
# ---------------------------------------------
#
# ---------------------sample 1------------------
#  source machine                                          quartz
# app                                                     laghos
# args                                   -p 1 -dim 2 -rs 2 -tf 3
# ranks                                                        1
# duration                                                0.1833
# BR_INS                                            8200000000.0
# LD_INS                                           19434000000.0
# SR_INS                                            6256000000.0
# TOT_INS                                          59954000000.0
# L1_LDM                                             202000000.0
# L1_STM                                             160000000.0
# L2_LDM                                               6000000.0
# L2_STM                                               4000000.0
# FP_SINGLE                                            3259234.0
# FP_DOUBLE                                        11407387387.0
# ARITH                                             8376314544.0
# IO Bytes Read                                          37771.0
# IO Bytes Written                                     2205834.0
# MEM_WCY                                            912000000.0
# REALTIME (sec)                                        8.763434
# PM_MATH_FLOP_CMPL                                          NaN
# L1-DCACHE-LOAD-MISSES                                      NaN
# L1-ICACHE-LOAD-MISSES                                      NaN
# Overhead                                              2.234566
# sid                                                         13
# target machine                                          quartz
# source Basic_DAXPY                                     0.34603
# source Basic_DAXPY_ATOMIC                             0.345529
# source Basic_IF_QUAD                                  0.920538
# source Basic_INDEXLIST                                0.475888
# source Basic_INDEXLIST_3LOOP                          0.555628
# source Basic_INIT3                                    2.245596
# source Basic_INIT_VIEW1D                              1.447279
# source Basic_INIT_VIEW1D_OFFSET                       1.635724
# source Basic_MAT_MAT_SHARED                           1.080305
# source Basic_MULADDSUB                                1.537314
# source Basic_NESTED_INIT                              0.646454
# source Basic_PI_ATOMIC                                0.073369
# source Basic_PI_REDUCE                                0.073875
# source Basic_REDUCE3_INT                              0.007783
# source Basic_REDUCE_STRUCT                            0.028808
# source Basic_TRAP_INT                                  0.20069
# source Lcals_DIFF_PREDICT                             2.007845
# source Lcals_EOS                                      1.222614
# source Lcals_FIRST_DIFF                               1.395403
# source Lcals_FIRST_MIN                                0.120171
# source Lcals_FIRST_SUM                                1.401646
# source Lcals_GEN_LIN_RECUR                            2.188445
# source Lcals_HYDRO_1D                                 1.295056
# source Lcals_HYDRO_2D                                   1.5761
# source Lcals_INT_PREDICT                              3.032338
# source Lcals_PLANCKIAN                                0.206229
# source Lcals_TRIDIAG_ELIM                             2.441377
# source Polybench_2MM                                 10.412638
# source Polybench_3MM                                 13.742798
# source Polybench_ADI                                  0.500692
# source Polybench_ATAX                                 0.288476
# source Polybench_FDTD_2D                              1.123367
# source Polybench_FLOYD_WARSHALL                       8.317259
# source Polybench_GEMM                                 7.462155
# source Polybench_GEMVER                               0.068463
# source Polybench_GESUMMV                              0.063355
# source Polybench_HEAT_3D                              0.954756
# source Polybench_JACOBI_1D                             2.28643
# source Polybench_JACOBI_2D                            3.465528
# source Polybench_MVT                                  0.272925
# source Stream_ADD                                     1.286901
# source Stream_COPY                                     1.23231
# source Stream_DOT                                     0.968376
# source Stream_MUL                                     1.253137
# source Stream_TRIAD                                    1.27983
# source Apps_CONVECTION3DPA                            0.226707
# source Apps_DEL_DOT_VEC_2D                            0.952945
# source Apps_DIFFUSION3DPA                             0.792499
# source Apps_ENERGY                                    3.336461
# source Apps_FIR                                       0.467996
# source Apps_HALOEXCHANGE                              0.028261
# source Apps_HALOEXCHANGE_FUSED                         0.02823
# source Apps_LTIMES                                    1.431187
# source Apps_LTIMES_NOVIEW                             1.452036
# source Apps_MASS3DPA                                  0.159564
# source Apps_NODAL_ACCUMULATION_3D                     0.538354
# source Apps_PRESSURE                                  2.666671
# source Apps_VOL3D                                     1.387882
# source Algorithm_SCAN                                 0.099403
# source Algorithm_SORT                                 1.651874
# source Algorithm_SORTPAIRS                            1.921417
# source Algorithm_REDUCE_SUM                           0.013302
# source Algorithm_MEMSET                                0.04365
# source Algorithm_MEMCPY                               0.068495
# target Basic_DAXPY                                     0.34603
# target Basic_DAXPY_ATOMIC                             0.345529
# target Basic_IF_QUAD                                  0.920538
# target Basic_INDEXLIST                                0.475888
# target Basic_INDEXLIST_3LOOP                          0.555628
# target Basic_INIT3                                    2.245596
# target Basic_INIT_VIEW1D                              1.447279
# target Basic_INIT_VIEW1D_OFFSET                       1.635724
# target Basic_MAT_MAT_SHARED                           1.080305
# target Basic_MULADDSUB                                1.537314
# target Basic_NESTED_INIT                              0.646454
# target Basic_PI_ATOMIC                                0.073369
# target Basic_PI_REDUCE                                0.073875
# target Basic_REDUCE3_INT                              0.007783
# target Basic_REDUCE_STRUCT                            0.028808
# target Basic_TRAP_INT                                  0.20069
# target Lcals_DIFF_PREDICT                             2.007845
# target Lcals_EOS                                      1.222614
# target Lcals_FIRST_DIFF                               1.395403
# target Lcals_FIRST_MIN                                0.120171
# target Lcals_FIRST_SUM                                1.401646
# target Lcals_GEN_LIN_RECUR                            2.188445
# target Lcals_HYDRO_1D                                 1.295056
# target Lcals_HYDRO_2D                                   1.5761
# target Lcals_INT_PREDICT                              3.032338
# target Lcals_PLANCKIAN                                0.206229
# target Lcals_TRIDIAG_ELIM                             2.441377
# target Polybench_2MM                                 10.412638
# target Polybench_3MM                                 13.742798
# target Polybench_ADI                                  0.500692
# target Polybench_ATAX                                 0.288476
# target Polybench_FDTD_2D                              1.123367
# target Polybench_FLOYD_WARSHALL                       8.317259
# target Polybench_GEMM                                 7.462155
# target Polybench_GEMVER                               0.068463
# target Polybench_GESUMMV                              0.063355
# target Polybench_HEAT_3D                              0.954756
# target Polybench_JACOBI_1D                             2.28643
# target Polybench_JACOBI_2D                            3.465528
# target Polybench_MVT                                  0.272925
# target Stream_ADD                                     1.286901
# target Stream_COPY                                     1.23231
# target Stream_DOT                                     0.968376
# target Stream_MUL                                     1.253137
# target Stream_TRIAD                                    1.27983
# target Apps_CONVECTION3DPA                            0.226707
# target Apps_DEL_DOT_VEC_2D                            0.952945
# target Apps_DIFFUSION3DPA                             0.792499
# target Apps_ENERGY                                    3.336461
# target Apps_FIR                                       0.467996
# target Apps_HALOEXCHANGE                              0.028261
# target Apps_HALOEXCHANGE_FUSED                         0.02823
# target Apps_LTIMES                                    1.431187
# target Apps_LTIMES_NOVIEW                             1.452036
# target Apps_MASS3DPA                                  0.159564
# target Apps_NODAL_ACCUMULATION_3D                     0.538354
# target Apps_PRESSURE                                  2.666671
# target Apps_VOL3D                                     1.387882
# target Algorithm_SCAN                                 0.099403
# target Algorithm_SORT                                 1.651874
# target Algorithm_SORTPAIRS                            1.921417
# target Algorithm_REDUCE_SUM                           0.013302
# target Algorithm_MEMSET                                0.04365
# target Algorithm_MEMCPY                               0.068495
# Name: 0, dtype: object
#
# ---------------------sample 2------------------
#  source machine                                          quartz
# app                                                     laghos
# args                                   -p 1 -dim 2 -rs 2 -tf 3
# ranks                                                        1
# duration                                                0.1833
# BR_INS                                            8200000000.0
# LD_INS                                           19434000000.0
# SR_INS                                            6256000000.0
# TOT_INS                                          59954000000.0
# L1_LDM                                             202000000.0
# L1_STM                                             160000000.0
# L2_LDM                                               6000000.0
# L2_STM                                               4000000.0
# FP_SINGLE                                            3259234.0
# FP_DOUBLE                                        11407387387.0
# ARITH                                             8376314544.0
# IO Bytes Read                                          37771.0
# IO Bytes Written                                     2205834.0
# MEM_WCY                                            912000000.0
# REALTIME (sec)                                        8.763434
# PM_MATH_FLOP_CMPL                                          NaN
# L1-DCACHE-LOAD-MISSES                                      NaN
# L1-ICACHE-LOAD-MISSES                                      NaN
# Overhead                                              2.234566
# sid                                                         13
# target machine                                            ruby
# source Basic_DAXPY                                     0.34603
# source Basic_DAXPY_ATOMIC                             0.345529
# source Basic_IF_QUAD                                  0.920538
# source Basic_INDEXLIST                                0.475888
# source Basic_INDEXLIST_3LOOP                          0.555628
# source Basic_INIT3                                    2.245596
# source Basic_INIT_VIEW1D                              1.447279
# source Basic_INIT_VIEW1D_OFFSET                       1.635724
# source Basic_MAT_MAT_SHARED                           1.080305
# source Basic_MULADDSUB                                1.537314
# source Basic_NESTED_INIT                              0.646454
# source Basic_PI_ATOMIC                                0.073369
# source Basic_PI_REDUCE                                0.073875
# source Basic_REDUCE3_INT                              0.007783
# source Basic_REDUCE_STRUCT                            0.028808
# source Basic_TRAP_INT                                  0.20069
# source Lcals_DIFF_PREDICT                             2.007845
# source Lcals_EOS                                      1.222614
# source Lcals_FIRST_DIFF                               1.395403
# source Lcals_FIRST_MIN                                0.120171
# source Lcals_FIRST_SUM                                1.401646
# source Lcals_GEN_LIN_RECUR                            2.188445
# source Lcals_HYDRO_1D                                 1.295056
# source Lcals_HYDRO_2D                                   1.5761
# source Lcals_INT_PREDICT                              3.032338
# source Lcals_PLANCKIAN                                0.206229
# source Lcals_TRIDIAG_ELIM                             2.441377
# source Polybench_2MM                                 10.412638
# source Polybench_3MM                                 13.742798
# source Polybench_ADI                                  0.500692
# source Polybench_ATAX                                 0.288476
# source Polybench_FDTD_2D                              1.123367
# source Polybench_FLOYD_WARSHALL                       8.317259
# source Polybench_GEMM                                 7.462155
# source Polybench_GEMVER                               0.068463
# source Polybench_GESUMMV                              0.063355
# source Polybench_HEAT_3D                              0.954756
# source Polybench_JACOBI_1D                             2.28643
# source Polybench_JACOBI_2D                            3.465528
# source Polybench_MVT                                  0.272925
# source Stream_ADD                                     1.286901
# source Stream_COPY                                     1.23231
# source Stream_DOT                                     0.968376
# source Stream_MUL                                     1.253137
# source Stream_TRIAD                                    1.27983
# source Apps_CONVECTION3DPA                            0.226707
# source Apps_DEL_DOT_VEC_2D                            0.952945
# source Apps_DIFFUSION3DPA                             0.792499
# source Apps_ENERGY                                    3.336461
# source Apps_FIR                                       0.467996
# source Apps_HALOEXCHANGE                              0.028261
# source Apps_HALOEXCHANGE_FUSED                         0.02823
# source Apps_LTIMES                                    1.431187
# source Apps_LTIMES_NOVIEW                             1.452036
# source Apps_MASS3DPA                                  0.159564
# source Apps_NODAL_ACCUMULATION_3D                     0.538354
# source Apps_PRESSURE                                  2.666671
# source Apps_VOL3D                                     1.387882
# source Algorithm_SCAN                                 0.099403
# source Algorithm_SORT                                 1.651874
# source Algorithm_SORTPAIRS                            1.921417
# source Algorithm_REDUCE_SUM                           0.013302
# source Algorithm_MEMSET                                0.04365
# source Algorithm_MEMCPY                               0.068495
# target Basic_DAXPY                                    0.320378
# target Basic_DAXPY_ATOMIC                             0.315267
# target Basic_IF_QUAD                                  0.407475
# target Basic_INDEXLIST                                0.379011
# target Basic_INDEXLIST_3LOOP                          0.535553
# target Basic_INIT3                                    1.334957
# target Basic_INIT_VIEW1D                              0.774008
# target Basic_INIT_VIEW1D_OFFSET                       0.782189
# target Basic_MAT_MAT_SHARED                           0.847726
# target Basic_MULADDSUB                                 0.93115
# target Basic_NESTED_INIT                              0.315727
# target Basic_PI_ATOMIC                                0.026816
# target Basic_PI_REDUCE                                0.027579
# target Basic_REDUCE3_INT                              0.007776
# target Basic_REDUCE_STRUCT                            0.033637
# target Basic_TRAP_INT                                 0.064533
# target Lcals_DIFF_PREDICT                             1.353433
# target Lcals_EOS                                      0.853542
# target Lcals_FIRST_DIFF                               1.313793
# target Lcals_FIRST_MIN                                0.100972
# target Lcals_FIRST_SUM                                1.311883
# target Lcals_GEN_LIN_RECUR                            1.957471
# target Lcals_HYDRO_1D                                 1.097705
# target Lcals_HYDRO_2D                                 1.184961
# target Lcals_INT_PREDICT                              2.254296
# target Lcals_PLANCKIAN                                 0.42921
# target Lcals_TRIDIAG_ELIM                             1.596756
# target Polybench_2MM                                  5.031454
# target Polybench_3MM                                  6.473441
# target Polybench_ADI                                  0.361763
# target Polybench_ATAX                                 0.150965
# target Polybench_FDTD_2D                              0.901387
# target Polybench_FLOYD_WARSHALL                       7.489794
# target Polybench_GEMM                                  3.93013
# target Polybench_GEMVER                               0.039387
# target Polybench_GESUMMV                              0.078155
# target Polybench_HEAT_3D                              0.623884
# target Polybench_JACOBI_1D                            2.087074
# target Polybench_JACOBI_2D                            2.760375
# target Polybench_MVT                                  0.153825
# target Stream_ADD                                     1.072823
# target Stream_COPY                                    1.160189
# target Stream_DOT                                     1.214833
# target Stream_MUL                                     1.168698
# target Stream_TRIAD                                   1.059676
# target Apps_CONVECTION3DPA                            0.168952
# target Apps_DEL_DOT_VEC_2D                            0.708527
# target Apps_DIFFUSION3DPA                             0.556429
# target Apps_ENERGY                                     2.46431
# target Apps_FIR                                       0.426309
# target Apps_HALOEXCHANGE                              0.027664
# target Apps_HALOEXCHANGE_FUSED                        0.027797
# target Apps_LTIMES                                    0.854043
# target Apps_LTIMES_NOVIEW                              0.85551
# target Apps_MASS3DPA                                  0.112851
# target Apps_NODAL_ACCUMULATION_3D                     0.296646
# target Apps_PRESSURE                                  1.891615
# target Apps_VOL3D                                     0.971668
# target Algorithm_SCAN                                 0.105262
# target Algorithm_SORT                                 1.487352
# target Algorithm_SORTPAIRS                            1.518336
# target Algorithm_REDUCE_SUM                           0.015589
# target Algorithm_MEMSET                               0.030739
# target Algorithm_MEMCPY                               0.077259
# Name: 1, dtype: object

# %% [markdown]
# ## Calculating the relative performance

# %%
data_df = helper_functions.calc_relative_performances(data_df)
print('\n---------------------sample 1------------------\n', data_df.iloc[0,:])
print('\n---------------------sample 2------------------\n', data_df.iloc[1,:])
# Out:
# ---------------------sample 1------------------
#  source machine                                          quartz
# app                                                     laghos
# args                                   -p 1 -dim 2 -rs 2 -tf 3
# ranks                                                        1
# duration                                                0.1833
# BR_INS                                            8200000000.0
# LD_INS                                           19434000000.0
# SR_INS                                            6256000000.0
# TOT_INS                                          59954000000.0
# L1_LDM                                             202000000.0
# L1_STM                                             160000000.0
# L2_LDM                                               6000000.0
# L2_STM                                               4000000.0
# FP_SINGLE                                            3259234.0
# FP_DOUBLE                                        11407387387.0
# ARITH                                             8376314544.0
# IO Bytes Read                                          37771.0
# IO Bytes Written                                     2205834.0
# MEM_WCY                                            912000000.0
# REALTIME (sec)                                        8.763434
# PM_MATH_FLOP_CMPL                                          NaN
# L1-DCACHE-LOAD-MISSES                                      NaN
# L1-ICACHE-LOAD-MISSES                                      NaN
# Overhead                                              2.234566
# sid                                                         13
# target machine                                          quartz
# source Basic_DAXPY                                     0.34603
# source Basic_DAXPY_ATOMIC                             0.345529
# source Basic_IF_QUAD                                  0.920538
# source Basic_INDEXLIST                                0.475888
# source Basic_INDEXLIST_3LOOP                          0.555628
# source Basic_INIT3                                    2.245596
# source Basic_INIT_VIEW1D                              1.447279
# source Basic_INIT_VIEW1D_OFFSET                       1.635724
# source Basic_MAT_MAT_SHARED                           1.080305
# source Basic_MULADDSUB                                1.537314
# source Basic_NESTED_INIT                              0.646454
# source Basic_PI_ATOMIC                                0.073369
# source Basic_PI_REDUCE                                0.073875
# source Basic_REDUCE3_INT                              0.007783
# source Basic_REDUCE_STRUCT                            0.028808
# source Basic_TRAP_INT                                  0.20069
# source Lcals_DIFF_PREDICT                             2.007845
# source Lcals_EOS                                      1.222614
# source Lcals_FIRST_DIFF                               1.395403
# source Lcals_FIRST_MIN                                0.120171
# source Lcals_FIRST_SUM                                1.401646
# source Lcals_GEN_LIN_RECUR                            2.188445
# source Lcals_HYDRO_1D                                 1.295056
# source Lcals_HYDRO_2D                                   1.5761
# source Lcals_INT_PREDICT                              3.032338
# source Lcals_PLANCKIAN                                0.206229
# source Lcals_TRIDIAG_ELIM                             2.441377
# source Polybench_2MM                                 10.412638
# source Polybench_3MM                                 13.742798
# source Polybench_ADI                                  0.500692
# source Polybench_ATAX                                 0.288476
# source Polybench_FDTD_2D                              1.123367
# source Polybench_FLOYD_WARSHALL                       8.317259
# source Polybench_GEMM                                 7.462155
# source Polybench_GEMVER                               0.068463
# source Polybench_GESUMMV                              0.063355
# source Polybench_HEAT_3D                              0.954756
# source Polybench_JACOBI_1D                             2.28643
# source Polybench_JACOBI_2D                            3.465528
# source Polybench_MVT                                  0.272925
# source Stream_ADD                                     1.286901
# source Stream_COPY                                     1.23231
# source Stream_DOT                                     0.968376
# source Stream_MUL                                     1.253137
# source Stream_TRIAD                                    1.27983
# source Apps_CONVECTION3DPA                            0.226707
# source Apps_DEL_DOT_VEC_2D                            0.952945
# source Apps_DIFFUSION3DPA                             0.792499
# source Apps_ENERGY                                    3.336461
# source Apps_FIR                                       0.467996
# source Apps_HALOEXCHANGE                              0.028261
# source Apps_HALOEXCHANGE_FUSED                         0.02823
# source Apps_LTIMES                                    1.431187
# source Apps_LTIMES_NOVIEW                             1.452036
# source Apps_MASS3DPA                                  0.159564
# source Apps_NODAL_ACCUMULATION_3D                     0.538354
# source Apps_PRESSURE                                  2.666671
# source Apps_VOL3D                                     1.387882
# source Algorithm_SCAN                                 0.099403
# source Algorithm_SORT                                 1.651874
# source Algorithm_SORTPAIRS                            1.921417
# source Algorithm_REDUCE_SUM                           0.013302
# source Algorithm_MEMSET                                0.04365
# source Algorithm_MEMCPY                               0.068495
# target Basic_DAXPY                                     0.34603
# target Basic_DAXPY_ATOMIC                             0.345529
# target Basic_IF_QUAD                                  0.920538
# target Basic_INDEXLIST                                0.475888
# target Basic_INDEXLIST_3LOOP                          0.555628
# target Basic_INIT3                                    2.245596
# target Basic_INIT_VIEW1D                              1.447279
# target Basic_INIT_VIEW1D_OFFSET                       1.635724
# target Basic_MAT_MAT_SHARED                           1.080305
# target Basic_MULADDSUB                                1.537314
# target Basic_NESTED_INIT                              0.646454
# target Basic_PI_ATOMIC                                0.073369
# target Basic_PI_REDUCE                                0.073875
# target Basic_REDUCE3_INT                              0.007783
# target Basic_REDUCE_STRUCT                            0.028808
# target Basic_TRAP_INT                                  0.20069
# target Lcals_DIFF_PREDICT                             2.007845
# target Lcals_EOS                                      1.222614
# target Lcals_FIRST_DIFF                               1.395403
# target Lcals_FIRST_MIN                                0.120171
# target Lcals_FIRST_SUM                                1.401646
# target Lcals_GEN_LIN_RECUR                            2.188445
# target Lcals_HYDRO_1D                                 1.295056
# target Lcals_HYDRO_2D                                   1.5761
# target Lcals_INT_PREDICT                              3.032338
# target Lcals_PLANCKIAN                                0.206229
# target Lcals_TRIDIAG_ELIM                             2.441377
# target Polybench_2MM                                 10.412638
# target Polybench_3MM                                 13.742798
# target Polybench_ADI                                  0.500692
# target Polybench_ATAX                                 0.288476
# target Polybench_FDTD_2D                              1.123367
# target Polybench_FLOYD_WARSHALL                       8.317259
# target Polybench_GEMM                                 7.462155
# target Polybench_GEMVER                               0.068463
# target Polybench_GESUMMV                              0.063355
# target Polybench_HEAT_3D                              0.954756
# target Polybench_JACOBI_1D                             2.28643
# target Polybench_JACOBI_2D                            3.465528
# target Polybench_MVT                                  0.272925
# target Stream_ADD                                     1.286901
# target Stream_COPY                                     1.23231
# target Stream_DOT                                     0.968376
# target Stream_MUL                                     1.253137
# target Stream_TRIAD                                    1.27983
# target Apps_CONVECTION3DPA                            0.226707
# target Apps_DEL_DOT_VEC_2D                            0.952945
# target Apps_DIFFUSION3DPA                             0.792499
# target Apps_ENERGY                                    3.336461
# target Apps_FIR                                       0.467996
# target Apps_HALOEXCHANGE                              0.028261
# target Apps_HALOEXCHANGE_FUSED                         0.02823
# target Apps_LTIMES                                    1.431187
# target Apps_LTIMES_NOVIEW                             1.452036
# target Apps_MASS3DPA                                  0.159564
# target Apps_NODAL_ACCUMULATION_3D                     0.538354
# target Apps_PRESSURE                                  2.666671
# target Apps_VOL3D                                     1.387882
# target Algorithm_SCAN                                 0.099403
# target Algorithm_SORT                                 1.651874
# target Algorithm_SORTPAIRS                            1.921417
# target Algorithm_REDUCE_SUM                           0.013302
# target Algorithm_MEMSET                                0.04365
# target Algorithm_MEMCPY                               0.068495
# relative performance                                       1.0
# target_sid                                                  13
# Name: 0, dtype: object
#
# ---------------------sample 2------------------
#  source machine                                          quartz
# app                                                     laghos
# args                                   -p 1 -dim 2 -rs 2 -tf 3
# ranks                                                        1
# duration                                                0.1833
# BR_INS                                            8200000000.0
# LD_INS                                           19434000000.0
# SR_INS                                            6256000000.0
# TOT_INS                                          59954000000.0
# L1_LDM                                             202000000.0
# L1_STM                                             160000000.0
# L2_LDM                                               6000000.0
# L2_STM                                               4000000.0
# FP_SINGLE                                            3259234.0
# FP_DOUBLE                                        11407387387.0
# ARITH                                             8376314544.0
# IO Bytes Read                                          37771.0
# IO Bytes Written                                     2205834.0
# MEM_WCY                                            912000000.0
# REALTIME (sec)                                        8.763434
# PM_MATH_FLOP_CMPL                                          NaN
# L1-DCACHE-LOAD-MISSES                                      NaN
# L1-ICACHE-LOAD-MISSES                                      NaN
# Overhead                                              2.234566
# sid                                                         13
# target machine                                            ruby
# source Basic_DAXPY                                     0.34603
# source Basic_DAXPY_ATOMIC                             0.345529
# source Basic_IF_QUAD                                  0.920538
# source Basic_INDEXLIST                                0.475888
# source Basic_INDEXLIST_3LOOP                          0.555628
# source Basic_INIT3                                    2.245596
# source Basic_INIT_VIEW1D                              1.447279
# source Basic_INIT_VIEW1D_OFFSET                       1.635724
# source Basic_MAT_MAT_SHARED                           1.080305
# source Basic_MULADDSUB                                1.537314
# source Basic_NESTED_INIT                              0.646454
# source Basic_PI_ATOMIC                                0.073369
# source Basic_PI_REDUCE                                0.073875
# source Basic_REDUCE3_INT                              0.007783
# source Basic_REDUCE_STRUCT                            0.028808
# source Basic_TRAP_INT                                  0.20069
# source Lcals_DIFF_PREDICT                             2.007845
# source Lcals_EOS                                      1.222614
# source Lcals_FIRST_DIFF                               1.395403
# source Lcals_FIRST_MIN                                0.120171
# source Lcals_FIRST_SUM                                1.401646
# source Lcals_GEN_LIN_RECUR                            2.188445
# source Lcals_HYDRO_1D                                 1.295056
# source Lcals_HYDRO_2D                                   1.5761
# source Lcals_INT_PREDICT                              3.032338
# source Lcals_PLANCKIAN                                0.206229
# source Lcals_TRIDIAG_ELIM                             2.441377
# source Polybench_2MM                                 10.412638
# source Polybench_3MM                                 13.742798
# source Polybench_ADI                                  0.500692
# source Polybench_ATAX                                 0.288476
# source Polybench_FDTD_2D                              1.123367
# source Polybench_FLOYD_WARSHALL                       8.317259
# source Polybench_GEMM                                 7.462155
# source Polybench_GEMVER                               0.068463
# source Polybench_GESUMMV                              0.063355
# source Polybench_HEAT_3D                              0.954756
# source Polybench_JACOBI_1D                             2.28643
# source Polybench_JACOBI_2D                            3.465528
# source Polybench_MVT                                  0.272925
# source Stream_ADD                                     1.286901
# source Stream_COPY                                     1.23231
# source Stream_DOT                                     0.968376
# source Stream_MUL                                     1.253137
# source Stream_TRIAD                                    1.27983
# source Apps_CONVECTION3DPA                            0.226707
# source Apps_DEL_DOT_VEC_2D                            0.952945
# source Apps_DIFFUSION3DPA                             0.792499
# source Apps_ENERGY                                    3.336461
# source Apps_FIR                                       0.467996
# source Apps_HALOEXCHANGE                              0.028261
# source Apps_HALOEXCHANGE_FUSED                         0.02823
# source Apps_LTIMES                                    1.431187
# source Apps_LTIMES_NOVIEW                             1.452036
# source Apps_MASS3DPA                                  0.159564
# source Apps_NODAL_ACCUMULATION_3D                     0.538354
# source Apps_PRESSURE                                  2.666671
# source Apps_VOL3D                                     1.387882
# source Algorithm_SCAN                                 0.099403
# source Algorithm_SORT                                 1.651874
# source Algorithm_SORTPAIRS                            1.921417
# source Algorithm_REDUCE_SUM                           0.013302
# source Algorithm_MEMSET                                0.04365
# source Algorithm_MEMCPY                               0.068495
# target Basic_DAXPY                                    0.320378
# target Basic_DAXPY_ATOMIC                             0.315267
# target Basic_IF_QUAD                                  0.407475
# target Basic_INDEXLIST                                0.379011
# target Basic_INDEXLIST_3LOOP                          0.535553
# target Basic_INIT3                                    1.334957
# target Basic_INIT_VIEW1D                              0.774008
# target Basic_INIT_VIEW1D_OFFSET                       0.782189
# target Basic_MAT_MAT_SHARED                           0.847726
# target Basic_MULADDSUB                                 0.93115
# target Basic_NESTED_INIT                              0.315727
# target Basic_PI_ATOMIC                                0.026816
# target Basic_PI_REDUCE                                0.027579
# target Basic_REDUCE3_INT                              0.007776
# target Basic_REDUCE_STRUCT                            0.033637
# target Basic_TRAP_INT                                 0.064533
# target Lcals_DIFF_PREDICT                             1.353433
# target Lcals_EOS                                      0.853542
# target Lcals_FIRST_DIFF                               1.313793
# target Lcals_FIRST_MIN                                0.100972
# target Lcals_FIRST_SUM                                1.311883
# target Lcals_GEN_LIN_RECUR                            1.957471
# target Lcals_HYDRO_1D                                 1.097705
# target Lcals_HYDRO_2D                                 1.184961
# target Lcals_INT_PREDICT                              2.254296
# target Lcals_PLANCKIAN                                 0.42921
# target Lcals_TRIDIAG_ELIM                             1.596756
# target Polybench_2MM                                  5.031454
# target Polybench_3MM                                  6.473441
# target Polybench_ADI                                  0.361763
# target Polybench_ATAX                                 0.150965
# target Polybench_FDTD_2D                              0.901387
# target Polybench_FLOYD_WARSHALL                       7.489794
# target Polybench_GEMM                                  3.93013
# target Polybench_GEMVER                               0.039387
# target Polybench_GESUMMV                              0.078155
# target Polybench_HEAT_3D                              0.623884
# target Polybench_JACOBI_1D                            2.087074
# target Polybench_JACOBI_2D                            2.760375
# target Polybench_MVT                                  0.153825
# target Stream_ADD                                     1.072823
# target Stream_COPY                                    1.160189
# target Stream_DOT                                     1.214833
# target Stream_MUL                                     1.168698
# target Stream_TRIAD                                   1.059676
# target Apps_CONVECTION3DPA                            0.168952
# target Apps_DEL_DOT_VEC_2D                            0.708527
# target Apps_DIFFUSION3DPA                             0.556429
# target Apps_ENERGY                                     2.46431
# target Apps_FIR                                       0.426309
# target Apps_HALOEXCHANGE                              0.027664
# target Apps_HALOEXCHANGE_FUSED                        0.027797
# target Apps_LTIMES                                    0.854043
# target Apps_LTIMES_NOVIEW                              0.85551
# target Apps_MASS3DPA                                  0.112851
# target Apps_NODAL_ACCUMULATION_3D                     0.296646
# target Apps_PRESSURE                                  1.891615
# target Apps_VOL3D                                     0.971668
# target Algorithm_SCAN                                 0.105262
# target Algorithm_SORT                                 1.487352
# target Algorithm_SORTPAIRS                            1.518336
# target Algorithm_REDUCE_SUM                           0.015589
# target Algorithm_MEMSET                               0.030739
# target Algorithm_MEMCPY                               0.077259
# relative performance                                    1.3334
# target_sid                                                1442
# Name: 1, dtype: object

# %% [markdown]
# ## (Optional) Get relative performance statistics

# %%
from collections import defaultdict
raw_dict = defaultdict(list)
sum_dict = defaultdict(lambda: [0.0, 0])
max_dict = defaultdict(lambda: float('-inf'))
min_dict = defaultdict(lambda: float('inf'))

with open('rel_raw0.txt', 'w') as f:
    for index, row in data_df.iterrows():
        m_s = row['source machine']
        m_t = row['target machine']
        # speedup
        rel = row['relative performance']
        cur = sum_dict[(m_s, m_t)];
        sum_dict[(m_s, m_t)] = (cur[0]+rel, cur[1]+1)

        cur_min = min_dict[(m_s, m_t)]
        if (cur_min > rel) :
            min_dict[(m_s, m_t)] = rel;

        cur_max = max_dict[(m_s, m_t)]
        if (cur_max < rel) :
            max_dict[(m_s, m_t)] = rel;
        raw_dict[(m_s, m_t)].append(rel)
        #print(' %s %s %.3f' % (m_s, m_t, rel), file=f)

with open('speedup_min.txt', 'w') as f:
    for (m_s, m_t), rel in min_dict.items():
        print(f"({m_s}, {m_t}) : {rel}", file=f)

with open('speedup_max.txt', 'w') as f:
    for (m_s, m_t), rel in max_dict.items():
        print(f"({m_s}, {m_t}) : {rel}", file=f)

with open('speedup_avg.txt', 'w') as f:
    for (m_s, m_t), rel in sum_dict.items():
        print(f"({m_s}, {m_t}) : {rel[1]} {rel[0]/rel[1]}", file=f)

with open('speedup_raw.txt', 'w') as f:
    for (m_s, m_t), rel in raw_dict.items():
        print(f"({m_s}, {m_t}) : {rel}", file=f)

# %%
uniq_df = data_df.drop_duplicates(subset=['app', 'args', 'ranks'], inplace=False)
with open('uniq_app_arg_rank.txt', 'w') as f:
    for index, row in uniq_df.iterrows():
        print(f"{row['app']}, {row['ranks']}, {row['args']}", file=f)

# %% [markdown]
# ## Removing unneeded columns

# %%
# refined_df = data_df.copy()
refined_df = helper_functions.remove_unneeded_columns(data_df)
x_all, y_all = helper_functions.split_x_y(refined_df)

# %% [markdown]
# ## XGBoost model training setup

# %%
from xgboost import XGBRegressor
import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import make_scorer


# Intead of using 'mape' as the eval_metric pre-defined in xgboost,
# we define a custom mape evaluator to avoid the divide-by-zero issue
def xgb_mape(preds, dtrain):
   labels = dtrain.get_label()
   return('mape', -np.mean(np.abs((labels - preds) / (labels + 0.000001))))

n_estimators = 1500
max_depth = 6
eval_metric = xgb_mape

# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ## Test training setup (optional)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_all, y_all, test_size = 0.20, random_state = 0)
print('num train samples: ', len(x_train))
print('num test samples: ', len(x_test))

model = XGBRegressor(n_estimators=n_estimators, max_depth=max_depth)
model.fit(x_train, y_train)
print('test MAPE: %.3f' % mean_absolute_percentage_error(y_test, model.predict(x_test)))
print('train MAPE: %.3f' % mean_absolute_percentage_error(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
y_test_arr = y_test.to_numpy()
mape = np.abs(y_test_arr - y_pred)/y_test_arr
mae = np.abs(y_test_arr - y_pred)

print('test MAPE (min, max, avg): %.3f %.3f %.3f' % (min(mape), max(mape), mape.mean()))
print('test MAE (min, max, avg): %.3f %.3f %.3f' % (min(mae), max(mae), mae.mean()))

print('Y_truth (avg std): %.3f %.3f' % (np.mean(y_test), np.std(y_test)))
print('Y_pred (avg std): %.3f %.3f' % (np.mean(y_pred), np.std(y_pred)))

#len(y_test[y_test == 0])
# Out:
# num train samples:  3594
# num test samples:  899
# test MAPE: 0.158
# train MAPE: 0.004
# test MAPE (min, max, avg): 0.000 5.947 0.158
# test MAE (min, max, avg): 0.000 7.164 0.177
# Y_truth (avg std): 1.394 2.380
# Y_pred (avg std): 1.407 2.337

# %% [markdown]
# ## Random Split

# %%
# mape_scorer = make_scorer(helper_functions.MAPE)
# mape_scorer = helper_functions.get_mape_scorer()
mape_scorer = make_scorer(sklearn.metrics.mean_absolute_percentage_error)
model = XGBRegressor(n_estimators=n_estimators, max_depth=max_depth, eval_metric=xgb_mape)

# evaluate model
scores = cross_val_score(model, x_all, y_all, scoring=mape_scorer, cv=cv, n_jobs=-1)

# force scores to be positive
random_mapes = np.absolute(scores)
print('Mean MAPE: %.3f (%.3f)' % (random_mapes.mean(), random_mapes.std()) )


model = XGBRegressor(n_estimators=n_estimators, max_depth=max_depth, eval_metric='mae')
scores = cross_val_score(model, x_all, y_all, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
random_maes = np.absolute(scores)

print('Mean MAE: %.3f (%.3f)' % (random_maes.mean(), random_maes.std()) )
# Out:
# Mean MAPE: 0.158 (0.019)
# Mean MAE: 0.172 (0.028)

# %% [markdown]
# ## Holding out one app for model testing while using the rest apps for training

# %%
model = XGBRegressor(n_estimators=n_estimators, max_depth=max_depth, eval_metric=xgb_mape)
app_removed_names, app_removed_mapes, app_removed_maes = helper_functions.test_any_app_removed(data_df, n_estimators, max_depth, xgb_mape)
# Out:
# laghos mape (avg, std): 1.529 0.000
# kripke.exe mape (avg, std): 0.300 0.000
# miniVite mape (avg, std): 0.502 0.000
# TestDfft mape (avg, std): 1.156 0.000
# amg mape (avg, std): 0.604 0.000
# XSBench mape (avg, std): 1.003 0.000
# miniFE.x mape (avg, std): 0.286 0.000
# mean mape (avg, std, min, max): 0.768 0.436 0.286 1.529
# mean mse (avg, std, min, max): 5.766 8.304 0.140 22.156
# mean mae: (avg, std, min, max): 0.848 0.549 0.291 1.771

# %% [markdown]
# ## Test Some Args/Runs Removed

# %%
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split
# import helper_functions

# n_estimators = 1250
# max_depth = 6
# data_df = helper_functions.do_all_setup()

args_removed_mapes, args_removed_maes = helper_functions.test_args_removed(data_df, n_estimators, max_depth)

print(args_removed_mapes)
print(min(args_removed_mapes), max(args_removed_mapes))
print(args_removed_maes)
print(min(args_removed_maes), max(args_removed_maes))
# Out:
# there are 814 total args
# split sizes [899, 899, 899, 900, 896]
# args length of 163
# args length of 163
# args length of 163
# args length of 163
# args length of 162
# arg passed length 163
# Num test samples:  3594
# Num train samples:  899
# 0 of 5 has mape [0.13464184]
# arg passed length 163
# Num test samples:  3594
# Num train samples:  899
# 1 of 5 has mape [0.15767508]
# arg passed length 163
# Num test samples:  3594
# Num train samples:  899
# 2 of 5 has mape [0.13028098]
# arg passed length 163
# Num test samples:  3593
# Num train samples:  900
# 3 of 5 has mape [0.16026711]
# arg passed length 162
# Num test samples:  3597
# Num train samples:  896
# 4 of 5 has mape [0.14007071]
# [array([0.13464184]), array([0.15767508]), array([0.13028098]), array([0.16026711]), array([0.14007071])]
# [0.13028098] [0.16026711]
# [array([0.15453739]), array([0.15051768]), array([0.13250313]), array([0.15823618]), array([0.15187127])]
# [0.13250313] [0.15823618]

# %% [markdown]
# # Plot

# %%
print(len(app_removed_mapes))

for mapes in app_removed_mapes:
    print(min(mapes), max(mapes), np.mean(mapes), np.std(mapes))
    # print()
# np_temp = np.ndarray(app_removed_mapes)
# print(np.min(np_temp))

# %%
import matplotlib.pyplot as plt

def addlabels(x,y, y_err):
    for i in range(len(x)):
        plt.text(i,y[i] + 1, str(round(y[i], 2)) + ' (std: ' + str(round(y_err[i], 2)) + ')', ha='center')
        
# helper_functions.set_plt_size()
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

fig, ax = plt.subplots()


x = ['random split'] + ['1/5 of arguments removed'] + ['one app removed'] + (app_removed_names + ' removed').tolist()

# y = [0] + app_removed_mapes

avg_app_removed_mapes = []
std_app_removed_mapes = []
for i in range(len(app_removed_mapes)):
    avg_app_removed_mapes.append(np.mean(app_removed_mapes[i]))
    std_app_removed_mapes.append(np.std(app_removed_mapes[i]))
print(avg_app_removed_mapes)

y = [np.average(random_mapes)] + [np.average(args_removed_mapes)] + [np.average(avg_app_removed_mapes)] + avg_app_removed_mapes
errors = [np.std(random_mapes)] + [np.std(args_removed_mapes)] + [np.std(avg_app_removed_mapes)] + std_app_removed_mapes

# errors.append(np.std(random_mapes))
# errors[1] = np.std(args_removed_mapes))
# errors[2] = np.std(avg_app_removed_mapes)()
# errors = errors + std_app_removed_mapes



addlabels(x,y, errors)
# for i in range(3, 3 + len(std_app_removed_mapes)):
#     errors[i] = 0
# errors[] = 

ax.bar(x, y, ecolor='black', capsize=10)
# plt.bar(x, y)

ax.set_xticks(np.arange(0, (len(x)+1)))
plt.title("XGBoost MAPE")

plt.ylabel("MAPE")
plt.xlabel("Training/Testing Method")

# addlabels(x, y)

helper_functions.wrap_labels(ax, 10)

# plt.show()

# %%
import matplotlib.pyplot as plt

def addlabels(x,y, y_err):
    for i in range(len(x)):
        plt.text(i,y[i] + .001, str(round(y[i], 2)), ha='center')

# helper_functions.set_plt_size()
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

fig, ax = plt.subplots()


x = ['random split'] + ['1/5 of arguments removed'] + ['one app removed']

# y = [0] + app_removed_mapes

# avg_app_removed_maes = []
# std_app_removed_maes = []
# for i in range(len(app_removed_mapes)):
#     avg_app_removed_maes.append(np.mean(app_removed_mapes[i]))
#     std_app_removed_maes.append(np.std(app_removed_mapes[i]))
# print(avg_app_removed_mapes)

y = [np.average(random_maes)] + [np.average(args_removed_maes)] + [np.average(app_removed_maes)]
# errors = [np.std(random_mapes)] + [np.std(args_removed_mapes)] + [np.std(avg_app_removed_mapes)] + std_app_removed_mapes
# errors.append(np.std(random_mapes))
# errors[1] = np.std(args_removed_mapes))
# errors[2] = np.std(avg_app_removed_mapes)()
# errors = errors + std_app_removed_mapes



addlabels(x,y, errors)

ax.bar(x, y, capsize=10)
# plt.bar(x, y)

ax.set_xticks(np.arange(0, (len(x)+1)))
plt.title("XGBoost MAE")

plt.ylabel("MAE")
plt.xlabel("Training/Testing Method")

# addlabels(x, y)

helper_functions.wrap_labels(ax, 10)

# plt.show()
